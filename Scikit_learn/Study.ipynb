# %% [markdown]
# # 1.使用conda配置环境

# %%
conda create -n sklearn python=3.12
conda activate sklearn
# Out:
#   Cell In[2], line 1
#     conda create -n sklearn python=3.12
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 2.安装sklearn

# %% [markdown]
#  下载

# %%
pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: scikit-learn in d:\anaconda_environment\envs\sklearn\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in d:\anaconda_environment\envs\sklearn\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in d:\anaconda_environment\envs\sklearn\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda_environment\envs\sklearn\lib\site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda_environment\envs\sklearn\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 检查下载是否成功

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %% [markdown]
# # 3.数据集分割

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=42)

# %%
random_state=42 参数是一个随机数种子，用于确保每次分割数据集时都能得到相同的结果。这在实验和模型验证中非常有用，因为它确保了结果的可重复性

# %% [markdown]
# # 4.数据预处理

# %% [markdown]
# 检查，删除缺失值

# %%
import pandas as pd

print(df.isnull().sum())

# %% [markdown]
# 填充

# %%
from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(strategy="mean")#均值填充

# %% [markdown]
# 删除

# %%
df_clean = df.dropna(axie=0,how='any')

# %% [markdown]
# # 5.机器学习模型

# %% [markdown]
# ## 5.1分类模型

# %%
# 逻辑回归
